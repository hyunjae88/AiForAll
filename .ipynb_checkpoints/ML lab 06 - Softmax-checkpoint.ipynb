# %% [markdown]
# # Lecture 6-1

# %% [markdown]
# ## Softmax classification : Multinomial classification

# %% [markdown]
# ### 0. Review <br>
#  - Logistic regression 은 기존 선형 함수를 시그모이드 함수 (로지스틱 함수)에 넣은 형태

# %% [markdown]
# ### 1. Multinomial classification
#  - 여러 개의 클래스가 있다는 것
#  - ex) 학점 A, B, C로 나누는 것
#  - W * x 를 활용 (행렬 * 벡터)로 Y 예측값을 구함

# %% [markdown]
# ### 2.Softmax
#  - 3개의 값이 있을 때 그 결과값을 0~1, 그리고 그 결과 값들의 합이 1이 되게하는 것이 Softmax 함수
#  - 결과는 확률로도 볼 수 있다.
#  ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  - https://wikidocs.net/35476 참고
